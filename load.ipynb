# %%
from dotenv import load_dotenv
load_dotenv() 
import os
alchemy_key = os.environ["ALCHEMY"]
import keyring

import requests
import time
import sys
import traceback
import json
import pandas as pd
import sqlalchemy
import uuid
import urllib

conn_string = 'DRIVER={ODBC Driver 17 for SQL Server};SERVER=dev-web3.database.windows.net;DATABASE=sap;UID=web3_admin;PWD=' + keyring.get_password("sql-dev-web3", "web3_admin") + ";"
url = f'mssql+pyodbc:///?odbc_connect={urllib.parse.quote_plus(conn_string)}'
engine = sqlalchemy.create_engine(url, fast_executemany=True)

def create_df():
    df = pd.DataFrame(columns = ['blockNum', 'uniqueId', 'hash', 'from', 'to', 'value', 'erc721TokenId', 'erc1155Metadata', 'tokenId', 'asset', 'category', 'rawContract_value', 'rawContract_address', 'rawContract_decimal'])
    return df

## method that calls an API and retries it xx times in case of issues
def api_call(method:str, url:str, headers=None, payload=None, sleeper=2, retries=20):
    retry_counter = 0
    interupt = False

    while True:
        try:
            response = requests.request(method=method, url=url, headers=headers, data=payload)
            if response.status_code == 200:
                break
            else:
                retry_counter += 1
                if retry_counter <= retries:
                    print("retry API call #" + str(retry_counter) + " with: " + url)
                    time.sleep(retry_counter * sleeper)
                else:
                    print("retrying failed more than " + str(retries) + " times - start over")
                    return False
        except KeyboardInterrupt:
            interupt = True
            break        
        except:
            print('request issue, will retry with: ' + url)
            time.sleep(retry_counter * sleeper)
    
    if interupt == True:
        print("Execution ended successfully in api_call")
        sys.exit()
    else:
        return json.loads(response.text)

## iterate over api pagination
def api_load():
    contractAddresses = ['0x463de2a5c6e8bb0c87f4aa80a02689e6680f72c7', '0x6362364a37f34d39a1f4993fb595dab4116daf0d', '0x239b912cf695da50ad19e0c05337067e2eb55fe3', 
    '0x68e65cc375f10baf74ac41773658dd00b5de1eaa', '0x65d96f0d45606016e30c97ee039775de9722a7d2', '0x5a75fa233a06cfcf708549785598b428340b9261', '0xf855acf79501609d982e4793f588dff69fc4c7e6', 
    '0x05a28540de2869281fe8a39882fbadc96ec4766c', '0x88da4c6bffdaedf6b64bdb6060973f86a77830ec', '0x6f0e738ea607f3a6698a813d45849dc36f7f3328', '0x354e2edcfbcd2f3b5fdce8cad3730408c052804e', 
    '0x38c518400a3f9e2110dc52e6c92e37fb7378aaaf', '0xc42cb8538e0dea6459c5965876131120ba96122e', '0x0044c5a5a6f626b673224a3c0d71e851ad3d5153', '0xb00110cc12cdc8f666f33f4e52e4957ff594282f', 
    '0x65e217285f8c3bf615784c72e5874aa8ac35ef9d', '0xabfd6760151c7f9361cc5b03bbeebe2d7c0251da', '0x0f310489a6eb1eeefc815ff3f0574c88a4aaaa06', '0xc84403a38b90f1db216db398beb9c8acb3ad7d3b', 
    '0x80ea96d75a308144708570a8e84f50df5477ee8a', '0x62896f42cf1371b268db56e50d67c34f3eb1ad7a', '0x0bccab36f518f55e00f3efe2e828ae63cd2ac1b9', '0xf0b3aed0232b3c51693323e45878c9173b6c43fe', 
    '0x261bef4b19ace1398c6603ed7299296d0e32cc00', '0x54a34c14db1093eb6e602b83db9ecc8cb929ba5c', '0x7b6c20ab3aed15f8c695978282dc0a30093bec97', '0x04943c19896c776c78770429ec02c5384ee78292', 
    '0xa96c8e571b23a6cfc8ca6955c5d3ff03a13fa699', '0xe47838cb5874da9b8a40107abbf4edf75a7e7ba0', '0xeaa9938076748d7edd4df0721b3e3fe4077349d3', '0xa8cc5bde3134f73e25e5fa386d0e9c68ae3c77e6', 
    '0xb8802c009dd265b38e320214a7720ebd7a488827', '0x3b28baae3987502b436f6f37d1bcd7b87b517b27']

    url = f"https://polygon-mainnet.g.alchemy.com/v2/{alchemy_key}"
    payload_txt = {
        "id": 1,
        "jsonrpc": "2.0",
        "method": "alchemy_getAssetTransfers",
        "params": [
            {
                "fromBlock": "0x0",
                "toBlock": "latest",
                "contractAddresses": contractAddresses,
                "category": [
                        "erc20"
                ],
                "withMetadata": False,
                "excludeZeroValue": True,
                "maxCount": "0x3e8"
            }
        ]
    }
    payload = json.dumps(payload_txt)
    headers = {'Content-Type': 'text/plain'}

    df = create_df()
    pageKey = ''

    while True:
        try:
            if pageKey != '':
                payload_txt['params'][0]['pageKey'] = pageKey
                payload = json.dumps(payload_txt)

            response_json = api_call(method="POST", url=url, headers=headers, payload=payload)
            if type(response_json) == bool:
                print("Some API load issue with url: " + url)
                return False

            dfTemp = pd.json_normalize(response_json['result'], record_path='transfers', sep='_')
            df = pd.concat([df,dfTemp])

            if 'pageKey' in response_json['result']:
                pageKey = response_json['result']['pageKey']
                time.sleep(0.2)
            else:
                break
            
        except KeyboardInterrupt:
            print("Execution ended successfully")
            sys.exit()
        except requests.exceptions.RequestException as e:
            print("just a Request error, will retry in 2s...")
            time.sleep(2)
            continue
        except Exception as e:
            print("unexpected error")
            print(e)
            print(traceback.format_exc())
            return False
    return df
 
def transform(df:pd.DataFrame):
    df.drop(['erc721TokenId', 'erc1155Metadata', 'tokenId','rawContract_value','rawContract_decimal'], axis=1, inplace=True)

    int_columns = ["value"]    
    df[int_columns] = df[int_columns].apply(pd.to_numeric)

    df.rename(columns= {'rawContract_address':'contractAddress', 'from':'fromAddress', 'to':'toAddress'}, inplace=True)
    return df

def upsert_df( df: pd.DataFrame, table_name: str, primary_key_col: str):
    if df.shape[0] > 0:    
        # get datetime columns 
        date_cols = list(df.select_dtypes(include=['datetime64[ns, UTC]']).columns)
        dtype = {col : sqlalchemy.sql.sqltypes.DateTime for col in date_cols}

        table_name_to_transfer = f"temp_{uuid.uuid4().hex[:6]}"

        # replace the placeholder table with the dataframe
        df.to_sql(table_name_to_transfer, engine, if_exists='replace', index=False, dtype=dtype)

        # building the command terms
        cols_list = df.columns.tolist()
        cols_list_query = f'({(", ".join(cols_list))})'
        sr_cols_list = [f'Source.{i}' for i in cols_list]
        sr_cols_list_query = f'({(", ".join(sr_cols_list))})'
        up_cols_list = [f'{i}=Source.{i}' for i in cols_list]
        up_cols_list_query = f'{", ".join(up_cols_list)}'
            
        # fill values that should be interpreted as "NULL" with None
        def fill_null(vals: list) -> list:
            def bad(val):
                if isinstance(val, type(pd.NA)):
                    return True
                # the list of values you want to interpret as 'NULL' should be 
                # tweaked to your needs
                return val in ['NULL', 'nan', '', '', '-', '?']
            return tuple(i if not bad(i) else None for i in vals)

        # create the list of parameter indicators (?, ?, ?, etc...)
        # and the parameters, which are the values to be inserted
        params = [fill_null(row.tolist()) for _, row in df.iterrows()]
        param_slots = '('+', '.join(['?']*len(df.columns))+')'
            
        cmd = f'''
            MERGE {table_name} as Target
            USING {table_name_to_transfer} AS Source
            ON Target.{primary_key_col}=Source.{primary_key_col}
            
            WHEN NOT MATCHED BY Target THEN
            INSERT {cols_list_query} VALUES {sr_cols_list_query}

            WHEN MATCHED THEN
            UPDATE SET {up_cols_list_query};
            '''

        # execute the command to merge tables
        with engine.begin() as conn:
            conn.execute(cmd)

        engine.execute(f'DROP TABLE "{table_name_to_transfer}"')
    return True

def upsert(df: pd.DataFrame, table_name: str, primary_key_col: str):
    if df.shape[0] > 0:
        if df.shape[0] > 10000:
            print("Batch upload necessary")
            total_length = df.shape[0]
            batch_start = 0
            while batch_start < total_length:
                batch_end = batch_start + 10000
                upsert_df(df=df[batch_start:batch_end], table_name=table_name, primary_key_col=primary_key_col)
                print("Batch " + str(batch_end))
                batch_start = batch_end
        else:
            upsert_df(df=df, table_name=table_name, primary_key_col=primary_key_col)
    return df.shape[0]

def run():
    df = False
    while type(df) == bool:
        df = api_load()

    if df.shape[0] == 0:
        return None
    else:
        df = transform(df)
        loaded = upsert(df, table_name='toucan_nct' , primary_key_col='uniqueId')
        return loaded
        # return df

# %%
run()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'from'. (156) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\matth\OneDrive\Desktop\MyLocal\Toucan\load.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> run()
#
# c:\Users\matth\OneDrive\Desktop\MyLocal\Toucan\load.ipynb Cell 2 in run()
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=210'>211</a> else:
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=211'>212</a>     df = transform(df)
# --> <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=212'>213</a>     loaded = upsert(df, table_name='toucan_nct' , primary_key_col='uniqueId')
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=213'>214</a>     return loaded
#
# c:\Users\matth\OneDrive\Desktop\MyLocal\Toucan\load.ipynb Cell 2 in upsert(df, table_name, primary_key_col)
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=198'>199</a>             batch_start = batch_end
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=199'>200</a>     else:
# --> <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=200'>201</a>         upsert_df(df=df, table_name=table_name, primary_key_col=primary_key_col)
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=201'>202</a> return df.shape[0]
#
# c:\Users\matth\OneDrive\Desktop\MyLocal\Toucan\load.ipynb Cell 2 in upsert_df(df, table_name, primary_key_col)
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=181'>182</a>     # execute the command to merge tables
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=182'>183</a>     with engine.begin() as conn:
# --> <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=183'>184</a>         conn.execute(cmd)
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=185'>186</a>     engine.execute(f'DROP TABLE "{table_name_to_transfer}"')
#     <a href='vscode-notebook-cell:/c%3A/Users/matth/OneDrive/Desktop/MyLocal/Toucan/load.ipynb#W1sZmlsZQ%3D%3D?line=186'>187</a> return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near the keyword 'from'. (156) (SQLExecDirectW)")
# [SQL:
#             MERGE toucan_nct as Target
#             USING temp_4a0d7e AS Source
#             ON Target.uniqueId=Source.uniqueId
#
#             WHEN NOT MATCHED BY Target THEN
#             INSERT (blockNum, uniqueId, hash, from, to, value, asset, category, contractAddress) VALUES (Source.blockNum, Source.uniqueId, Source.hash, Source.from, Source.to, Source.value, Source.asset, Source.category, Source.contractAddress)
#
#             WHEN MATCHED THEN
#             UPDATE SET blockNum=Source.blockNum, uniqueId=Source.uniqueId, hash=Source.hash, from=Source.from, to=Source.to, value=Source.value, asset=Source.asset, category=Source.category, contractAddress=Source.contractAddress;
#             ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
df
# Out:
#       blockNum                                           uniqueId  \
# 0    0x1341787  0x391c0000bd48d605f83c7e6165438ec69a903efc509d...
# 1    0x13462aa  0x4cd4ed0c5186146343df108f691f6ad30cc4650f44e9...
# 2    0x134638a  0x7fe7d37c3d4e94cd30bbe0e0287d73978b27500f311a...
# 3    0x134639a  0xde6e943a1930fd79afefeb8f916160a02b931fe0804b...
# 4    0x13463a5  0xa5001abc6732d725ca65908f66c665a4f4a78f14a441...
# ..         ...                                                ...
# 602  0x1ed1967  0xbf271102c90bf4c23dd51488ac8a91839ce2d5225850...
# 603  0x1ed1967  0xbf271102c90bf4c23dd51488ac8a91839ce2d5225850...
# 604  0x1ee6efe  0x78551ebf115296903bf2cb8d4adf9f6b8e7ec1f017dd...
# 605  0x1ee6efe  0x78551ebf115296903bf2cb8d4adf9f6b8e7ec1f017dd...
# 606  0x1ee8eae  0x3dcd9106fdc0d2e16c0370159bb9f5cafbc20484a483...
#
#                                                   hash  \
# 0    0x391c0000bd48d605f83c7e6165438ec69a903efc509d...
# 1    0x4cd4ed0c5186146343df108f691f6ad30cc4650f44e9...
# 2    0x7fe7d37c3d4e94cd30bbe0e0287d73978b27500f311a...
# 3    0xde6e943a1930fd79afefeb8f916160a02b931fe0804b...
# 4    0xa5001abc6732d725ca65908f66c665a4f4a78f14a441...
# ..                                                 ...
# 602  0xbf271102c90bf4c23dd51488ac8a91839ce2d5225850...
# 603  0xbf271102c90bf4c23dd51488ac8a91839ce2d5225850...
# 604  0x78551ebf115296903bf2cb8d4adf9f6b8e7ec1f017dd...
# 605  0x78551ebf115296903bf2cb8d4adf9f6b8e7ec1f017dd...
# 606  0x3dcd9106fdc0d2e16c0370159bb9f5cafbc20484a483...
#
#                                            from  \
# 0    0x0000000000000000000000000000000000000000
# 1    0x0000000000000000000000000000000000000000
# 2    0x0000000000000000000000000000000000000000
# 3    0x0000000000000000000000000000000000000000
# 4    0x0000000000000000000000000000000000000000
# ..                                          ...
# 602  0xd838290e877e0188a4a44700463419ed96c16107
# 603  0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca
# 604  0xd838290e877e0188a4a44700463419ed96c16107
# 605  0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca
# 606  0x79c2d72552df1c5d551b812eca906a90ce9d840a
#
#                                              to    value               asset  \
# 0    0x5e037e2f5c92dc9e180426171b62da65d3ad5325    100.0   TCO2-VCS-674-2014
# 1    0xaf529400ff068afbdc907c699b9184a4381481b0   3000.0  TCO2-VCS-1162-2015
# 2    0xaf529400ff068afbdc907c699b9184a4381481b0   7000.0  TCO2-VCS-1162-2015
# 3    0xaf529400ff068afbdc907c699b9184a4381481b0   9174.0  TCO2-VCS-1577-2013
# 4    0xaf529400ff068afbdc907c699b9184a4381481b0  10000.0  TCO2-VCS-1577-2015
# ..                                          ...      ...                 ...
# 602  0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca     10.4  TCO2-VCS-1052-2012
# 603  0x0000000000000000000000000000000000000000     10.4  TCO2-VCS-1052-2012
# 604  0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca      1.0  TCO2-VCS-1052-2012
# 605  0x0000000000000000000000000000000000000000      1.0  TCO2-VCS-1052-2012
# 606  0x0000000000000000000000000000000000000000      1.0   TCO2-VCS-674-2014
#
#     category                             contractAddress
# 0      erc20  0x62896f42cf1371b268db56e50d67c34f3eb1ad7a
# 1      erc20  0x261bef4b19ace1398c6603ed7299296d0e32cc00
# 2      erc20  0x261bef4b19ace1398c6603ed7299296d0e32cc00
# 3      erc20  0x38c518400a3f9e2110dc52e6c92e37fb7378aaaf
# 4      erc20  0x04943c19896c776c78770429ec02c5384ee78292
# ..       ...                                         ...
# 602    erc20  0x463de2a5c6e8bb0c87f4aa80a02689e6680f72c7
# 603    erc20  0x463de2a5c6e8bb0c87f4aa80a02689e6680f72c7
# 604    erc20  0x463de2a5c6e8bb0c87f4aa80a02689e6680f72c7
# 605    erc20  0x463de2a5c6e8bb0c87f4aa80a02689e6680f72c7
# 606    erc20  0x62896f42cf1371b268db56e50d67c34f3eb1ad7a
#
# [1607 rows x 9 columns]

# %%
if 'pageKey' in response_json['result']:
    print('yes')
else:
    print('no')
# Out:
# no

# %%
response_json
# Out:
# {'jsonrpc': '2.0',
#  'id': 1,
#  'result': {'transfers': [{'blockNum': '0x163317a',
#     'uniqueId': '0x8239c98641de618ae509880df7c543f7e1de8cb8147fa525551955f7ae789ace:log:373',
#     'hash': '0x8239c98641de618ae509880df7c543f7e1de8cb8147fa525551955f7ae789ace',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'value': 89225.00000000001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x12e4e59dfdb084840000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x163323c',
#     'uniqueId': '0x6a043edc750424ed1d1fcfa54dabdf91cbf8aaffd78c4d9d3f4f5f744f881eee:log:455',
#     'hash': '0x6a043edc750424ed1d1fcfa54dabdf91cbf8aaffd78c4d9d3f4f5f744f881eee',
#     'from': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 89225.00000000001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x12e4e59dfdb084840000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16338d8',
#     'uniqueId': '0x08ccfc1167357ee05e06eb0be06a05ee7d25796367257bc60c55d1ad8e92bb70:log:384',
#     'hash': '0x08ccfc1167357ee05e06eb0be06a05ee7d25796367257bc60c55d1ad8e92bb70',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'value': 68000,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0e664992288f22800000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x163393b',
#     'uniqueId': '0x49b0cb085ee0086c50014ad5ac08c8f346a4198b22c4997944bb8699b74325b5:log:360',
#     'hash': '0x49b0cb085ee0086c50014ad5ac08c8f346a4198b22c4997944bb8699b74325b5',
#     'from': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 68000,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0e664992288f22800000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a36',
#     'uniqueId': '0x554a13f5d33deca1c6ec33000062a07f7965b88308423125ff18619000d25034:log:263',
#     'hash': '0x554a13f5d33deca1c6ec33000062a07f7965b88308423125ff18619000d25034',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a36',
#     'uniqueId': '0x554a13f5d33deca1c6ec33000062a07f7965b88308423125ff18619000d25034:log:265',
#     'hash': '0x554a13f5d33deca1c6ec33000062a07f7965b88308423125ff18619000d25034',
#     'from': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a4f',
#     'uniqueId': '0xfdeb59c7d3d9514f63351f97e5bb8b4fdaecc6337324cd9fb458e48de7f98928:log:253',
#     'hash': '0xfdeb59c7d3d9514f63351f97e5bb8b4fdaecc6337324cd9fb458e48de7f98928',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a4f',
#     'uniqueId': '0xfdeb59c7d3d9514f63351f97e5bb8b4fdaecc6337324cd9fb458e48de7f98928:log:255',
#     'hash': '0xfdeb59c7d3d9514f63351f97e5bb8b4fdaecc6337324cd9fb458e48de7f98928',
#     'from': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a60',
#     'uniqueId': '0xf68d2063550d5d05aa6aeb9b68651af96526a99cd549488d3eed989ae1a1b9c5:log:222',
#     'hash': '0xf68d2063550d5d05aa6aeb9b68651af96526a99cd549488d3eed989ae1a1b9c5',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634a60',
#     'uniqueId': '0xf68d2063550d5d05aa6aeb9b68651af96526a99cd549488d3eed989ae1a1b9c5:log:224',
#     'hash': '0xf68d2063550d5d05aa6aeb9b68651af96526a99cd549488d3eed989ae1a1b9c5',
#     'from': '0x3fd0231b713018bf084a32ba54fb6901e8d7c075',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634dfd',
#     'uniqueId': '0x9f40907e04505cdb5ad13ee935f2a89020f610f99e16a1bd1007b47776d92466:log:154',
#     'hash': '0x9f40907e04505cdb5ad13ee935f2a89020f610f99e16a1bd1007b47776d92466',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634dfd',
#     'uniqueId': '0x9f40907e04505cdb5ad13ee935f2a89020f610f99e16a1bd1007b47776d92466:log:156',
#     'hash': '0x9f40907e04505cdb5ad13ee935f2a89020f610f99e16a1bd1007b47776d92466',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634dfd',
#     'uniqueId': '0x09fa9d03d5115909c910d45adb0f267bb4b354f8fb47b841705cc4af4128ab0a:log:393',
#     'hash': '0x09fa9d03d5115909c910d45adb0f267bb4b354f8fb47b841705cc4af4128ab0a',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634dfd',
#     'uniqueId': '0x09fa9d03d5115909c910d45adb0f267bb4b354f8fb47b841705cc4af4128ab0a:log:395',
#     'hash': '0x09fa9d03d5115909c910d45adb0f267bb4b354f8fb47b841705cc4af4128ab0a',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634e8e',
#     'uniqueId': '0xc988a975f37f5dd7f594a7eda30e2ad8784e7bc009874255e1819b5cc4a164e4:log:277',
#     'hash': '0xc988a975f37f5dd7f594a7eda30e2ad8784e7bc009874255e1819b5cc4a164e4',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634e8e',
#     'uniqueId': '0xc988a975f37f5dd7f594a7eda30e2ad8784e7bc009874255e1819b5cc4a164e4:log:279',
#     'hash': '0xc988a975f37f5dd7f594a7eda30e2ad8784e7bc009874255e1819b5cc4a164e4',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634ea6',
#     'uniqueId': '0x34093a4b4e3db3ce58d2a9a30d23c1118fe11caba94b1736f9baf839f7fada38:log:288',
#     'hash': '0x34093a4b4e3db3ce58d2a9a30d23c1118fe11caba94b1736f9baf839f7fada38',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634ea6',
#     'uniqueId': '0x34093a4b4e3db3ce58d2a9a30d23c1118fe11caba94b1736f9baf839f7fada38:log:290',
#     'hash': '0x34093a4b4e3db3ce58d2a9a30d23c1118fe11caba94b1736f9baf839f7fada38',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634eaf',
#     'uniqueId': '0x00682aae5da35e18c78f573c430f7d22e6591a7158bbd2e526005d2e7356582c:log:179',
#     'hash': '0x00682aae5da35e18c78f573c430f7d22e6591a7158bbd2e526005d2e7356582c',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1634eaf',
#     'uniqueId': '0x00682aae5da35e18c78f573c430f7d22e6591a7158bbd2e526005d2e7356582c:log:181',
#     'hash': '0x00682aae5da35e18c78f573c430f7d22e6591a7158bbd2e526005d2e7356582c',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1637786',
#     'uniqueId': '0x4f4014fae5c9a638bda555b925b78ba9bca31a3264900b7c328a2baf5acaa999:log:355',
#     'hash': '0x4f4014fae5c9a638bda555b925b78ba9bca31a3264900b7c328a2baf5acaa999',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x20494f58f26a0b0d93d4d42d7423dad10c7f7b27',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16378d4',
#     'uniqueId': '0xedfc10dcf18c6c6fe7252468d077aa2a8317261abe3aea511781a123bb17f5e1:log:247',
#     'hash': '0xedfc10dcf18c6c6fe7252468d077aa2a8317261abe3aea511781a123bb17f5e1',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x20494f58f26a0b0d93d4d42d7423dad10c7f7b27',
#     'value': 2999.0000000000005,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0xa2937c529df47c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16391df',
#     'uniqueId': '0x368ecdbab036fe7d5d291c10c987c1c7fa95c69ed0cbfa4d908a2eee0b005b48:log:443',
#     'hash': '0x368ecdbab036fe7d5d291c10c987c1c7fa95c69ed0cbfa4d908a2eee0b005b48',
#     'from': '0x20494f58f26a0b0d93d4d42d7423dad10c7f7b27',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 3000,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0xa2a15d09519be00000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x165b5d5',
#     'uniqueId': '0xbb9af07ca79550ee9538ab60681c74556feab1e05cc8fb545b99705aa8409518:log:340',
#     'hash': '0xbb9af07ca79550ee9538ab60681c74556feab1e05cc8fb545b99705aa8409518',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'value': 61525,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0d0746e5169454340000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x165b7ae',
#     'uniqueId': '0x8ce884651bca8144e95a6a3e49d02683bad2a5bc6c78c64b44b2abcc8cc698ad:log:154',
#     'hash': '0x8ce884651bca8144e95a6a3e49d02683bad2a5bc6c78c64b44b2abcc8cc698ad',
#     'from': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 61525,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0d0746e5169454340000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x165ba44',
#     'uniqueId': '0x6c886a510632fd3f2b3021186f7f43db5b3f2eb54b86796bfb5f2ae92a23b53c:log:305',
#     'hash': '0x6c886a510632fd3f2b3021186f7f43db5b3f2eb54b86796bfb5f2ae92a23b53c',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'value': 16291.999999999998,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x037330eb4148d8100000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x165bf68',
#     'uniqueId': '0x7d4a62e338254d4535384dc28f09f99edd1fbe184c80932f397c0510e575d5c8:log:1',
#     'hash': '0x7d4a62e338254d4535384dc28f09f99edd1fbe184c80932f397c0510e575d5c8',
#     'from': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 16291.999999999998,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x037330eb4148d8100000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1660687',
#     'uniqueId': '0x7e61c1ec49380f522ee9b77a0f09b878964197d0a34342dd625bf489ecb8457b:log:310',
#     'hash': '0x7e61c1ec49380f522ee9b77a0f09b878964197d0a34342dd625bf489ecb8457b',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'value': 32183,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x06d0a4d853287c7c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16606af',
#     'uniqueId': '0x9746664970efddbf48a2da88151f9a5c0598584f93f6c798c94f6111cdf6224c:log:244',
#     'hash': '0x9746664970efddbf48a2da88151f9a5c0598584f93f6c798c94f6111cdf6224c',
#     'from': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 32183,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x06d0a4d853287c7c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1667422',
#     'uniqueId': '0x26b0298cbe7d830be7cb0b5651c00f7a4e9217e5039f76f7a0a2bc0ec8ae2158:log:39',
#     'hash': '0x26b0298cbe7d830be7cb0b5651c00f7a4e9217e5039f76f7a0a2bc0ec8ae2158',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'value': 62523,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0d3d60ed56f2e40c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1667466',
#     'uniqueId': '0xe41a1d71989ecf00ccee57d1b854b7f01c3c46aca9d3d60af25cadc06eabc0b8:log:0',
#     'hash': '0xe41a1d71989ecf00ccee57d1b854b7f01c3c46aca9d3d60af25cadc06eabc0b8',
#     'from': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 62523,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0d3d60ed56f2e40c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1667498',
#     'uniqueId': '0xa1a0544205f002b246018815d75febe995f0708a021907de6d6a3798046053ae:log:24',
#     'hash': '0xa1a0544205f002b246018815d75febe995f0708a021907de6d6a3798046053ae',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'value': 47484,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0a0e1ce052fc58700000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16674cb',
#     'uniqueId': '0xa3f228b587b450b8801c6ac160a94712f20856f17ce750a877e10ca69a26af5d:log:0',
#     'hash': '0xa3f228b587b450b8801c6ac160a94712f20856f17ce750a877e10ca69a26af5d',
#     'from': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 47484,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0a0e1ce052fc58700000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16674e0',
#     'uniqueId': '0x9a5de265b357148facc5fa55c8429a0f3b03431b347ad151c8db6ad695a3cf29:log:2',
#     'hash': '0x9a5de265b357148facc5fa55c8429a0f3b03431b347ad151c8db6ad695a3cf29',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'value': 42516,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0900cc06c493ebd00000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1667503',
#     'uniqueId': '0x9d88f16f5daae3f03292f167b735062b7f7778f8a79b4f63e98b60f852549a5e:log:0',
#     'hash': '0x9d88f16f5daae3f03292f167b735062b7f7778f8a79b4f63e98b60f852549a5e',
#     'from': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 42516,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0900cc06c493ebd00000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x166c74b',
#     'uniqueId': '0xfaaeceb8e900f005215f78f40aecbd20e2557401f5870c6a918f341d35b2a867:log:182',
#     'hash': '0xfaaeceb8e900f005215f78f40aecbd20e2557401f5870c6a918f341d35b2a867',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'value': 32850,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x06f4cd54593d9e080000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x166c786',
#     'uniqueId': '0x04ccbc3e3139f0c0f429928a7ee3f9f3f5071a1e60008f8ef4a9375eb2c326d9:log:261',
#     'hash': '0x04ccbc3e3139f0c0f429928a7ee3f9f3f5071a1e60008f8ef4a9375eb2c326d9',
#     'from': '0x4f8fcf15bc49fecba384a75d91f3cb60d4e92894',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 32850,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x06f4cd54593d9e080000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1677280',
#     'uniqueId': '0x01b7cdf9efc85edc1e248b91e9c0a2b6d9e51dec53dc67a8656a8fb2d184350d:log:8',
#     'hash': '0x01b7cdf9efc85edc1e248b91e9c0a2b6d9e51dec53dc67a8656a8fb2d184350d',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'value': 77453,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1066bc4c906b2a140000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1677317',
#     'uniqueId': '0xc89d82ebbaca2d0473166f25b45f1e2bccafc3e8e5d6c9264ff5d21d96ddbcca:log:0',
#     'hash': '0xc89d82ebbaca2d0473166f25b45f1e2bccafc3e8e5d6c9264ff5d21d96ddbcca',
#     'from': '0x2845ec77192ad7ba2faf67e63b49be6c8d4f8b20',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 77453,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1066bc4c906b2a140000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16773ce',
#     'uniqueId': '0x872e25f42c6580684e3b4b3ec253443f7976b46696e6361dde7bbfd6355abf4e:log:26',
#     'hash': '0x872e25f42c6580684e3b4b3ec253443f7976b46696e6361dde7bbfd6355abf4e',
#     'from': '0x0000000000000000000000000000000000000000',
#     'to': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'value': 24174,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x051e79a478a8a4f80000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1677412',
#     'uniqueId': '0xd88a47fb373141e10db5d0275dffca03357221d4e47c87c878d2287d85151fc1:log:5',
#     'hash': '0xd88a47fb373141e10db5d0275dffca03357221d4e47c87c878d2287d85151fc1',
#     'from': '0xc4652c97ae04a8cf6541c76cb96d9a7684ea1a8c',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 24174,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x051e79a478a8a4f80000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f1ecd',
#     'uniqueId': '0x6c742925b0804b8cac820bfd5289fba4eb40e2581b49273a5c637781ad15b379:log:171',
#     'hash': '0x6c742925b0804b8cac820bfd5289fba4eb40e2581b49273a5c637781ad15b379',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.03355111629074483,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x7732900053e201',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f1ecd',
#     'uniqueId': '0x6c742925b0804b8cac820bfd5289fba4eb40e2581b49273a5c637781ad15b379:log:173',
#     'hash': '0x6c742925b0804b8cac820bfd5289fba4eb40e2581b49273a5c637781ad15b379',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.03355111629074483,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x7732900053e201',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f1f71',
#     'uniqueId': '0x3cd9413362b789ca0a194deab3183a4d7b5483fdec05fec75c1845e556a7a578:log:160',
#     'hash': '0x3cd9413362b789ca0a194deab3183a4d7b5483fdec05fec75c1845e556a7a578',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.030162453545379605,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x6b289779206714',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f1f71',
#     'uniqueId': '0x3cd9413362b789ca0a194deab3183a4d7b5483fdec05fec75c1845e556a7a578:log:162',
#     'hash': '0x3cd9413362b789ca0a194deab3183a4d7b5483fdec05fec75c1845e556a7a578',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.030162453545379605,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x6b289779206714',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f20ef',
#     'uniqueId': '0xc493367392e05d5acb49bdaa71f89bee803f79d6a7b1eb46f0938972c7109921:log:248',
#     'hash': '0xc493367392e05d5acb49bdaa71f89bee803f79d6a7b1eb46f0938972c7109921',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.26,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x039bb49f599a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f20ef',
#     'uniqueId': '0xc493367392e05d5acb49bdaa71f89bee803f79d6a7b1eb46f0938972c7109921:log:250',
#     'hash': '0xc493367392e05d5acb49bdaa71f89bee803f79d6a7b1eb46f0938972c7109921',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.26,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x039bb49f599a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f228e',
#     'uniqueId': '0x3db06aea04f51bad5f791d18483679da203c30357827b15bc1627421ea31f54d:log:121',
#     'hash': '0x3db06aea04f51bad5f791d18483679da203c30357827b15bc1627421ea31f54d',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 1e-08,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x02540be400',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f228e',
#     'uniqueId': '0x3db06aea04f51bad5f791d18483679da203c30357827b15bc1627421ea31f54d:log:123',
#     'hash': '0x3db06aea04f51bad5f791d18483679da203c30357827b15bc1627421ea31f54d',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1e-08,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x02540be400',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f26ec',
#     'uniqueId': '0xec9defd12b279174c3fcb11ce9ab30434a896cb3d8367866ba6e6518706213f9:log:277',
#     'hash': '0xec9defd12b279174c3fcb11ce9ab30434a896cb3d8367866ba6e6518706213f9',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 0.3,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0429d069189e0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f26ec',
#     'uniqueId': '0xec9defd12b279174c3fcb11ce9ab30434a896cb3d8367866ba6e6518706213f9:log:279',
#     'hash': '0xec9defd12b279174c3fcb11ce9ab30434a896cb3d8367866ba6e6518706213f9',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.3,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0429d069189e0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f2886',
#     'uniqueId': '0xa84d7191000b964e3144d18223c2d07c1cdf66c981a9692752c0ab3459ff6aa9:log:115',
#     'hash': '0xa84d7191000b964e3144d18223c2d07c1cdf66c981a9692752c0ab3459ff6aa9',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 1e-12,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0f4240',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16f2886',
#     'uniqueId': '0xa84d7191000b964e3144d18223c2d07c1cdf66c981a9692752c0ab3459ff6aa9:log:117',
#     'hash': '0xa84d7191000b964e3144d18223c2d07c1cdf66c981a9692752c0ab3459ff6aa9',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1e-12,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0f4240',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fbeb4',
#     'uniqueId': '0x63aeb0fc0d1ffbc241910c7699db0c860fa946c71ca2d41af13f1d43fcd8bb2a:log:153',
#     'hash': '0x63aeb0fc0d1ffbc241910c7699db0c860fa946c71ca2d41af13f1d43fcd8bb2a',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xa81c94fd36d41397e3e67c4b9898368bc03cf359',
#     'value': 3,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x29a2241af62c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fc3b4',
#     'uniqueId': '0x51c6d3f0bcf36ae29120df1f141c705b637f64670bd79d1cae086e1ea99f5d84:log:157',
#     'hash': '0x51c6d3f0bcf36ae29120df1f141c705b637f64670bd79d1cae086e1ea99f5d84',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xb7c3b8bc63b0333fc0cb6b852ccf90a0f1acd8cd',
#     'value': 169,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0929589c9981040000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fc3e5',
#     'uniqueId': '0xc1e3d086879835e3048273efa796cf6e929035bce79071389feeea44b5b09030:log:147',
#     'hash': '0xc1e3d086879835e3048273efa796cf6e929035bce79071389feeea44b5b09030',
#     'from': '0xb7c3b8bc63b0333fc0cb6b852ccf90a0f1acd8cd',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 169,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0929589c9981040000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fc8cf',
#     'uniqueId': '0x3a76a40fe7788ca4b1675320045f88fb3f82c704e2701cded0af1409d4c9f0d7:log:140',
#     'hash': '0x3a76a40fe7788ca4b1675320045f88fb3f82c704e2701cded0af1409d4c9f0d7',
#     'from': '0xa81c94fd36d41397e3e67c4b9898368bc03cf359',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 3,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x29a2241af62c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fc91c',
#     'uniqueId': '0x2b3beca5addedd87c51569a910fe51d8804aa1ca670fc611504f633b5042dfa8:log:145',
#     'hash': '0x2b3beca5addedd87c51569a910fe51d8804aa1ca670fc611504f633b5042dfa8',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x25bdff8db8d80971935a7f38a0cf31dec62f7696',
#     'value': 4,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x3782dace9d900000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fcad7',
#     'uniqueId': '0x268f2c08506f3f5653927e49e2f91602428eddd86fcb17f095a158c44d7f7a05:log:116',
#     'hash': '0x268f2c08506f3f5653927e49e2f91602428eddd86fcb17f095a158c44d7f7a05',
#     'from': '0x25bdff8db8d80971935a7f38a0cf31dec62f7696',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.23,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1111d67bb1bb0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fd818',
#     'uniqueId': '0x63cac3d33edffd8a0fa7b66df3c69ad5129cfcf5d03a53c25173d2333d131705:log:126',
#     'hash': '0x63cac3d33edffd8a0fa7b66df3c69ad5129cfcf5d03a53c25173d2333d131705',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x335f04a40b09c1ec1792bedb0d023d6113e0dc75',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fd84e',
#     'uniqueId': '0xbbe80eed737074431511bed5ffd890fe307b66c84a37c0edf76d14431107d8a6:log:125',
#     'hash': '0xbbe80eed737074431511bed5ffd890fe307b66c84a37c0edf76d14431107d8a6',
#     'from': '0x335f04a40b09c1ec1792bedb0d023d6113e0dc75',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fe7dd',
#     'uniqueId': '0x4d8880401ec5fa15c95f85e29ed5caa7d87ba914592b3fcabaa3d94c69c1ce28:log:208',
#     'hash': '0x4d8880401ec5fa15c95f85e29ed5caa7d87ba914592b3fcabaa3d94c69c1ce28',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xd2be832911a252302bac09e30fc124a405e142df',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16fe810',
#     'uniqueId': '0x4101c2241a4666a400736fddf37f922a3aa818b217aa8c2e74d205478620f9d4:log:177',
#     'hash': '0x4101c2241a4666a400736fddf37f922a3aa818b217aa8c2e74d205478620f9d4',
#     'from': '0xd2be832911a252302bac09e30fc124a405e142df',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16ff176',
#     'uniqueId': '0xaff4bb2e4a837c9721b3ec11c1d48d02a6e9523e06a864fe173fcf10c6853221:log:177',
#     'hash': '0xaff4bb2e4a837c9721b3ec11c1d48d02a6e9523e06a864fe173fcf10c6853221',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xc3b6b7bcad0b55a5635d77235fb4b29970d4befd',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16ff5ae',
#     'uniqueId': '0xd96e882746f064484c7492502d7647440d3dc19fd6b0f14339157edf212ecedc:log:295',
#     'hash': '0xd96e882746f064484c7492502d7647440d3dc19fd6b0f14339157edf212ecedc',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x06630b7910d0983edd5a7cc2794f564f32480f5d',
#     'value': 3.42265567281451,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x2f7fb7334e959fb0',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x16ff62f',
#     'uniqueId': '0x2f3a335f68ac0c9aecec3dd88a1436072555045260c3908cb474308879cf8bf0:log:149',
#     'hash': '0x2f3a335f68ac0c9aecec3dd88a1436072555045260c3908cb474308879cf8bf0',
#     'from': '0x06630b7910d0983edd5a7cc2794f564f32480f5d',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 3.42265567281451,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x2f7fb7334e959fb0',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1700051',
#     'uniqueId': '0x27715c103c78e0d68474e2f1ead6182a9cc727813094201e4fee34e39b03d3ee:log:194',
#     'hash': '0x27715c103c78e0d68474e2f1ead6182a9cc727813094201e4fee34e39b03d3ee',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xbf985cb68894a79f5012d3417dd31db98aacff4a',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1700807',
#     'uniqueId': '0xd722dddcc860726751c8263aab77f5bd7168901cb7bdf8dc4652e3417281193b:log:129',
#     'hash': '0xd722dddcc860726751c8263aab77f5bd7168901cb7bdf8dc4652e3417281193b',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x4a62fde7ea3d349dd34f5216b953cb03c161e301',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1700827',
#     'uniqueId': '0x5b16bd455ae024b4cad1989fb2294812f67768cd0d6e94b3456f37dcf26f9459:log:178',
#     'hash': '0x5b16bd455ae024b4cad1989fb2294812f67768cd0d6e94b3456f37dcf26f9459',
#     'from': '0x4a62fde7ea3d349dd34f5216b953cb03c161e301',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x170521d',
#     'uniqueId': '0x1328401ef1b7247d1a1ba4646d167aecd313b451dcafe690e783b68e4570bc0d:log:340',
#     'hash': '0x1328401ef1b7247d1a1ba4646d167aecd313b451dcafe690e783b68e4570bc0d',
#     'from': '0xbf985cb68894a79f5012d3417dd31db98aacff4a',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1706110',
#     'uniqueId': '0x8ebfeb16f89e796e9d2aaa526c3dcd30f3133ac45a309e10eb7382cba47438eb:log:297',
#     'hash': '0x8ebfeb16f89e796e9d2aaa526c3dcd30f3133ac45a309e10eb7382cba47438eb',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x4a62fde7ea3d349dd34f5216b953cb03c161e301',
#     'value': 2,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1bc16d674ec80000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x170a908',
#     'uniqueId': '0xec6f7056562ccb90b2945f18391dedab266132bd1cb886f9e93ccbbd22024ce2:log:386',
#     'hash': '0xec6f7056562ccb90b2945f18391dedab266132bd1cb886f9e93ccbbd22024ce2',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x77d841647b738400f349edd85a44e67e9313ebd2',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1711534',
#     'uniqueId': '0x24ed7c48ec9fbc138c2a65fc443cd936a966891140796dc2d0e86e4242e23c06:log:537',
#     'hash': '0x24ed7c48ec9fbc138c2a65fc443cd936a966891140796dc2d0e86e4242e23c06',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x9fcd05f6ea78bdcea4018467e05c5597615c21be',
#     'value': 25,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x015af1d78b58c40000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x171fba8',
#     'uniqueId': '0xe520c78023fdfef4ce5666a4044055929cbe09b3df2280c851e7acb8c6bfe528:log:788',
#     'hash': '0xe520c78023fdfef4ce5666a4044055929cbe09b3df2280c851e7acb8c6bfe528',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'value': 1e-14,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x2710',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x171fba8',
#     'uniqueId': '0xe520c78023fdfef4ce5666a4044055929cbe09b3df2280c851e7acb8c6bfe528:log:790',
#     'hash': '0xe520c78023fdfef4ce5666a4044055929cbe09b3df2280c851e7acb8c6bfe528',
#     'from': '0x5594b25cb87ca46da17a5e3134b442e0f7298021',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1e-14,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x2710',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1724838',
#     'uniqueId': '0x055476d0ad501942b7462600ea2c7bc7eff59df46dfe47db116782f3bb4a14e0:log:343',
#     'hash': '0x055476d0ad501942b7462600ea2c7bc7eff59df46dfe47db116782f3bb4a14e0',
#     'from': '0xc3b6b7bcad0b55a5635d77235fb4b29970d4befd',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x016345785d8a0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x17258f5',
#     'uniqueId': '0x16f5233cb97be5642d81317c9755e4dba48cbd23bfd71e5ae82fe503350f0bf4:log:463',
#     'hash': '0x16f5233cb97be5642d81317c9755e4dba48cbd23bfd71e5ae82fe503350f0bf4',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0x810ac9882bc4b695f286c89ef1dc97d58d6f582d',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1725930',
#     'uniqueId': '0x9fb988fe7b2a422eae8d473f67426c97b039eb06b31c436bd801b2bca2bc4875:log:275',
#     'hash': '0x9fb988fe7b2a422eae8d473f67426c97b039eb06b31c436bd801b2bca2bc4875',
#     'from': '0x810ac9882bc4b695f286c89ef1dc97d58d6f582d',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
# ...
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.756072647492461,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x185ed2c4d19161a9',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a5fcba',
#     'uniqueId': '0x345ae082e55ec233e0c678ac3c4490e1b8ed84be4a449e8eded90d58bac69cc3:log:181',
#     'hash': '0x345ae082e55ec233e0c678ac3c4490e1b8ed84be4a449e8eded90d58bac69cc3',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.756072647492461,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x185ed2c4d19161a9',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6527a',
#     'uniqueId': '0x12aaf75ad10ddc2d955f5e9d72d69d36ba8e605e8d9b0b88103e0eac8272a649:log:282',
#     'hash': '0x12aaf75ad10ddc2d955f5e9d72d69d36ba8e605e8d9b0b88103e0eac8272a649',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 16,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0xde0b6b3a76400000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6527a',
#     'uniqueId': '0x12aaf75ad10ddc2d955f5e9d72d69d36ba8e605e8d9b0b88103e0eac8272a649:log:284',
#     'hash': '0x12aaf75ad10ddc2d955f5e9d72d69d36ba8e605e8d9b0b88103e0eac8272a649',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 16,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0xde0b6b3a76400000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66aa2',
#     'uniqueId': '0xff8defaff402c08c72c8e31a46763c4b688e80bfc73562f51adb696c5b079a97:log:245',
#     'hash': '0xff8defaff402c08c72c8e31a46763c4b688e80bfc73562f51adb696c5b079a97',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.8106182274085154,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x19209baf4c883175',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66aa2',
#     'uniqueId': '0xff8defaff402c08c72c8e31a46763c4b688e80bfc73562f51adb696c5b079a97:log:247',
#     'hash': '0xff8defaff402c08c72c8e31a46763c4b688e80bfc73562f51adb696c5b079a97',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.8106182274085154,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x19209baf4c883175',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66b81',
#     'uniqueId': '0x982769c0a3217dec56882a557c817818a4f849741c960d562598e522f3785f09:log:719',
#     'hash': '0x982769c0a3217dec56882a557c817818a4f849741c960d562598e522f3785f09',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 0.001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x038d7ea4c68000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66b81',
#     'uniqueId': '0x982769c0a3217dec56882a557c817818a4f849741c960d562598e522f3785f09:log:721',
#     'hash': '0x982769c0a3217dec56882a557c817818a4f849741c960d562598e522f3785f09',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x038d7ea4c68000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66baa',
#     'uniqueId': '0xaa8c73d954aaa0f438e7fdc66145fef6fa873ccb0209d784aaef16dfd467547f:log:377',
#     'hash': '0xaa8c73d954aaa0f438e7fdc66145fef6fa873ccb0209d784aaef16dfd467547f',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 0.0001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x5af3107a4000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a66baa',
#     'uniqueId': '0xaa8c73d954aaa0f438e7fdc66145fef6fa873ccb0209d784aaef16dfd467547f:log:379',
#     'hash': '0xaa8c73d954aaa0f438e7fdc66145fef6fa873ccb0209d784aaef16dfd467547f',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 0.0001,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x5af3107a4000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a67e14',
#     'uniqueId': '0x7722e225dd2ad8f28cffc247fb57554fc2f066e95215e90d7ffeba9484ea658c:log:241',
#     'hash': '0x7722e225dd2ad8f28cffc247fb57554fc2f066e95215e90d7ffeba9484ea658c',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcb76251e20927d515e2644a495bb20ec8df0eb15',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6869e',
#     'uniqueId': '0x1bfad4370d599273d4c77d24c6e82b48b88f38b6e69d70adf29be5defecf7693:log:211',
#     'hash': '0x1bfad4370d599273d4c77d24c6e82b48b88f38b6e69d70adf29be5defecf7693',
#     'from': '0xcb76251e20927d515e2644a495bb20ec8df0eb15',
#     'to': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'value': 1,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0de0b6b3a7640000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6baad',
#     'uniqueId': '0x596d5da72444e07d300110573be273b3f5ece726160e123e4018385d8cbde774:log:340',
#     'hash': '0x596d5da72444e07d300110573be273b3f5ece726160e123e4018385d8cbde774',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.7603785293096033,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x186e1ef20db935bc',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6baad',
#     'uniqueId': '0x596d5da72444e07d300110573be273b3f5ece726160e123e4018385d8cbde774:log:342',
#     'hash': '0x596d5da72444e07d300110573be273b3f5ece726160e123e4018385d8cbde774',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.7603785293096033,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x186e1ef20db935bc',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6bc34',
#     'uniqueId': '0x1496345dab9d9ceef59ff8124c24f8a0aff6a700f4b438284315765769797878:log:208',
#     'hash': '0x1496345dab9d9ceef59ff8124c24f8a0aff6a700f4b438284315765769797878',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.7603765642306965,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x186e1d2885e4ae7e',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a6bc34',
#     'uniqueId': '0x1496345dab9d9ceef59ff8124c24f8a0aff6a700f4b438284315765769797878:log:210',
#     'hash': '0x1496345dab9d9ceef59ff8124c24f8a0aff6a700f4b438284315765769797878',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.7603765642306965,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x186e1d2885e4ae7e',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a743c9',
#     'uniqueId': '0x79cfa864cfe784299d13dcca1fcfd21e5e0fda14cce1e9ffb16ca41c3c30ddbc:log:268',
#     'hash': '0x79cfa864cfe784299d13dcca1fcfd21e5e0fda14cce1e9ffb16ca41c3c30ddbc',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xdb8c07473162a637041e3581c3d702eef50b201e',
#     'value': 75,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0410d586a20a4c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a74469',
#     'uniqueId': '0x1e2cfbd9f8a70b455219162766801f09b0f9340bf2ba03583d4dc91988d9076b:log:131',
#     'hash': '0x1e2cfbd9f8a70b455219162766801f09b0f9340bf2ba03583d4dc91988d9076b',
#     'from': '0xdb8c07473162a637041e3581c3d702eef50b201e',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 75,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x0410d586a20a4c0000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a745a1',
#     'uniqueId': '0xfbb309f5b3d67fffec618b5ebf4d2e7789cf2f7ca2f2e58f68e98e17938b84f3:log:127',
#     'hash': '0xfbb309f5b3d67fffec618b5ebf4d2e7789cf2f7ca2f2e58f68e98e17938b84f3',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xdb8c07473162a637041e3581c3d702eef50b201e',
#     'value': 100,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x056bc75e2d63100000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a745be',
#     'uniqueId': '0x765a76ae8d28aa5a57b995c19f76c1fabf984e01a95b283d9913b28e09c9dc31:log:133',
#     'hash': '0x765a76ae8d28aa5a57b995c19f76c1fabf984e01a95b283d9913b28e09c9dc31',
#     'from': '0xdb8c07473162a637041e3581c3d702eef50b201e',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 86,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x04a97d605a3b980000',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a751e2',
#     'uniqueId': '0xc734f76acb9ff6fe69ce2efd6c8a998d5e203cddd2858a7d36868dcb22078b0e:log:239',
#     'hash': '0xc734f76acb9ff6fe69ce2efd6c8a998d5e203cddd2858a7d36868dcb22078b0e',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.8272079374982515,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x195b8bf02d5b80f5',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a751e2',
#     'uniqueId': '0xc734f76acb9ff6fe69ce2efd6c8a998d5e203cddd2858a7d36868dcb22078b0e:log:241',
#     'hash': '0xc734f76acb9ff6fe69ce2efd6c8a998d5e203cddd2858a7d36868dcb22078b0e',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.8272079374982515,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x195b8bf02d5b80f5',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a751fd',
#     'uniqueId': '0x6d402704bce3b2a9d522176a685e1f532ffd597ae95015203c0cb158216788f8:log:194',
#     'hash': '0x6d402704bce3b2a9d522176a685e1f532ffd597ae95015203c0cb158216788f8',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.8272058595653002,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x195b8a0c5ee6ea5b',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a751fd',
#     'uniqueId': '0x6d402704bce3b2a9d522176a685e1f532ffd597ae95015203c0cb158216788f8:log:196',
#     'hash': '0x6d402704bce3b2a9d522176a685e1f532ffd597ae95015203c0cb158216788f8',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.8272058595653002,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x195b8a0c5ee6ea5b',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a7d387',
#     'uniqueId': '0x30ea480a915f4820576544e858b6db3e52a57cabd684f0b00108eb833f9412f0:log:290',
#     'hash': '0x30ea480a915f4820576544e858b6db3e52a57cabd684f0b00108eb833f9412f0',
#     'from': '0x2f800db0fdb5223b3c3f354886d907a671414a7f',
#     'to': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'value': 1.9502000477345853,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1b10809c5e2b7842',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}},
#    {'blockNum': '0x1a7d387',
#     'uniqueId': '0x30ea480a915f4820576544e858b6db3e52a57cabd684f0b00108eb833f9412f0:log:292',
#     'hash': '0x30ea480a915f4820576544e858b6db3e52a57cabd684f0b00108eb833f9412f0',
#     'from': '0xcefb61af5325c0c100cbd77eb4c9f51d17b189ca',
#     'to': '0x0000000000000000000000000000000000000000',
#     'value': 1.9502000477345853,
#     'erc721TokenId': None,
#     'erc1155Metadata': None,
#     'tokenId': None,
#     'asset': 'TCO2-VCS-191-2008',
#     'category': 'erc20',
#     'rawContract': {'value': '0x1b10809c5e2b7842',
#      'address': '0xb139c4cc9d20a3618e9a2268d73eff18c496b991',
#      'decimal': '0x12'}}],
#   'pageKey': '6dc43dee-face-4916-bcac-6732c2896886'}}
